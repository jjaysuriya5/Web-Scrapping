# %%
# https://www.zomato.com/bangalore/hyderabadi-spice-3-electronic-city/reviews

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import os 

import pandas as pd
import numpy as np

# %%
path = 'C:\\Users\\Administrator\\Desktop\\Python\\Data Scraping\\Day 1'
os.chdir(path)
browser = webdriver.Firefox()

# %%
url = 'https://www.zomato.com/bangalore/hyderabadi-spice-3-electronic-city/reviews'
browser.get(url)

# %%
html = browser.page_source
soup = BeautifulSoup(html )

# %%
els = browser.find_elements_by_class_name('item respageMenu-item restaurant-tab-item-jumbo-track ')

# %%
len(els)
# Out:
# 0

# %%
p =  '/html/body/div[7]/div[1]/div/div[1]/div[3]/div/div[3]/div[1]/div[1]/div[1]/div/div[3]/a[2]'
el =browser.find_elements_by_xpath(p)
el[0].click()

# %%
bt
# Out:
# <a class="item default-section-title everyone empty" data-sort="reviews-dd">All Reviews <span class="grey-text">1531</span></a>

# %%
a = [i for i in soup.find_all( 'div', {'id' : 'selectors'})]

# %%
for i in a:
    print(i)
#     print(i.find_elements_by_class_name('item'))
# Out:
# <div class="review-sorting text-tabs selectors ui secondary pointing menu mt0" data-limit="5" id="selectors">
# <a class="item default-section-title top active selected" data-sort="reviews-top">Popular <span class="grey-text">2</span></a>
# <a class="item default-section-title everyone empty" data-sort="reviews-dd">All Reviews <span class="grey-text">1531</span></a>
# <a class="item default-section-title everyone empty" data-sort="reviews-delivery">Delivery Reviews <span class="grey-text">521</span></a>
# <div class="right item review-sort sortby" style="padding-bottom: 19px;">
# <div class="ui floating labeled dropdown button" data-limit="5" id="sort-container" tabindex="0">
# <span class="sort-sel text">Date<span class="right lh26px"> ↓</span></span>
# <div class="sort-options menu" style="left:auto; right:0; width: auto;" tabindex="-1">
# ...

# %%
browser.find_element_by_class_name

# %%
browser.find_elements_by_id_name('item')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-099707d843ea> in <module>
# ----> 1 browser.find_elements_by_id_name('item')
#
# AttributeError: 'WebDriver' object has no attribute 'find_elements_by_id_name'

# %%
a = [i for i in soup.find_all( 'div', {'id' : 'selectors'})] 
bt = a[0].find_all('a' , class_= 'item default-section-title everyone empty')[0]
bt
# Out:
# <a class="item default-section-title everyone empty" data-sort="reviews-dd">All Reviews <span class="grey-text">1531</span></a>

# %%
for i in browser.find_elements_by_class_name('zred'):
    print(i.text.strip())
# Out:
# Biryani
# North Indian
#
#
#
#
# Debapriya Paul
# 1530 others
# LOAD MORE
# Add a Zomato spoonback to your blog. ›

# %%
url = 'https://www.zomato.com/bangalore/hyderabadi-spice-3-electronic-city/reviews'
browser.get(url)

# %%
import re

# %%
for i in browser.find_elements_by_class_name('item'):
    if  re.search('.*All Reviews.*' , i.text.strip()):
        i.click()

# %%
# p =  '/html/body/div[7]/div[1]/div/div[1]/div[3]/div/div[3]/div[1]/div[1]/div[1]/div/div[3]/a[2]'
# el =browser.find_elements_by_xpath(p)
# el[0].click()

# %%
import time

# %%
while True :
    count = 0
    for i in browser.find_elements_by_class_name('zred'):
        if i.text.strip() == 'LOAD MORE' :
            i.click()
            count = 1
            time.sleep(3)
    if count == 0 :
        break

# %%
html = browser.page_source
soup = BeautifulSoup(html)

# %%
name =[]
for i in soup.find_all('div' , class_ = 'ui segment clearfix  brtop '):
    print(i)
# Out:
# <div class="header nowrap ui left">
# <a data-entity_id="90003442" href="https://www.zomato.com/users/akesh-jain-90003442">
#             Akesh Jain
#           </a>
# </div>
# <div class="header nowrap ui left">
# <a data-entity_id="123332504" href="https://www.zomato.com/users/aftab-ahmad-123332504">
#             Aftab Ahmad
#           </a>
# </div>
# <div class="header nowrap ui left">
# <a data-entity_id="60924164" href="https://www.zomato.com/users/sajid-husaen-60924164">
#             Sajid Husaen
#           </a>
# </div>
# <div class="header nowrap ui left">
# <a data-entity_id="73990301" href="https://www.zomato.com/users/javvaji-srianilkumar-73990301">
#             Javvaji Srianilkumar
#           </a>
# </div>
# <div class="header nowrap ui left">
# <a data-entity_id="118251360" href="https://www.zomato.com/users/eswar-j-118251360">
#             Eswar J
#           </a>
# </div>
# <div class="header nowrap ui left">
# ...
